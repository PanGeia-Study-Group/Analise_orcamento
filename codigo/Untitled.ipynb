# %% [markdown]
# # Análise possíveis CSVs do governo

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/3_dados_csv/2021_Receitas.csv', encoding="ISO-8859-1", sep = ';')

# %%
df
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR                            NOME ÓRGÃO SUPERIOR  \
# 0                       63000                       Advocacia-Geral da União
# 1                       63000                       Advocacia-Geral da União
# 2                       37000                   Controladoria-Geral da União
# 3                       22000  Ministério da Agricultura, Pecuária e Abastec
# 4                       22000  Ministério da Agricultura, Pecuária e Abastec
# ...                       ...                                            ...
# 129586                  20000                       Presidência da República
# 129587                  20000                       Presidência da República
# 129588                  20000                       Presidência da República
# 129589                  20000                       Presidência da República
# 129590                  20000                       Presidência da República
#
# ...

# %%
df.dtypes
# Out:
# CÓDIGO ÓRGÃO SUPERIOR         int64
# NOME ÓRGÃO SUPERIOR          object
# CÓDIGO ÓRGÃO                  int64
# NOME ÓRGÃO                   object
# CÓDIGO UNIDADE GESTORA        int64
# NOME UNIDADE GESTORA         object
# CATEGORIA ECONÔMICA          object
# ORIGEM RECEITA               object
# ESPÉCIE RECEITA              object
# DETALHAMENTO                 object
# VALOR PREVISTO ATUALIZADO    object
# VALOR LANÇADO                object
# VALOR REALIZADO              object
# PERCENTUAL REALIZADO         object
# DATA LANÇAMENTO              object
# ANO EXERCÍCIO                 int64
# dtype: object

# %%
df['VALOR REALIZADO'] = df['VALOR REALIZADO'].str.replace(',','.').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_38108/1715985951.py in <module>
# ----> 1 df['VALOR REALIZADO'] = df['VALOR REALIZADO'].str.replace(',','.').astype(float)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df[df['CÓDIGO ÓRGÃO SUPERIOR'] == 26000]['VALOR REALIZADO'].sum()
# Out:
# 28427112709.22
