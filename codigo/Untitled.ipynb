# %% [markdown]
# # Análise possíveis CSVs do governo

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/3_dados_csv/2021_Receitas.csv', encoding="ISO-8859-1", sep = ';')
df2 = pd.read_csv('../dados/3_dados_csv/2019_OrcamentoDespesa.csv', encoding="ISO-8859-1", sep = ';')

# %%
df.head(5)
# Out:
#    CÓDIGO ÓRGÃO SUPERIOR                            NOME ÓRGÃO SUPERIOR  \
# 0                  63000                       Advocacia-Geral da União
# 1                  63000                       Advocacia-Geral da União
# 2                  37000                   Controladoria-Geral da União
# 3                  22000  Ministério da Agricultura, Pecuária e Abastec
# 4                  22000  Ministério da Agricultura, Pecuária e Abastec
#
#    CÓDIGO ÓRGÃO                                         NOME ÓRGÃO  \
# 0         63000  Advocacia-Geral da União - Unidades com víncul...
# 1         63000  Advocacia-Geral da União - Unidades com víncul...
# 2         37000  Controladoria-Geral da União - Unidades com ví...
# 3         22211                Companhia Nacional de Abastecimento
# 4         22211                Companhia Nacional de Abastecimento
#
#    CÓDIGO UNIDADE GESTORA                           NOME UNIDADE GESTORA  \
# ...

# %%
df['NOME ÓRGÃO SUPERIOR'].value_counts()
# Out:
# Ministério da Educação                           38529
# Ministério da Economia                           32361
# Ministério da Defesa                             13032
# Ministério da Justiça e Segurança Pública         5726
# Ministério da Agricultura, Pecuária e Abastec     5610
# Ministério da Infraestrutura                      5088
# Ministério da Ciência, Tecnologia, Inovações      4605
# Ministério de Minas e Energia                     4392
# Ministério das Comunicações                       3981
# Ministério da Saúde                               3957
# Ministério do Desenvolvimento Regional            3874
# Ministério do Meio Ambiente                       3816
# Ministério do Turismo                             3064
# Ministério da Cidadania                            502
# Ministério das Relações Exteriores                 492
# Presidência da República                           358
# Ministério da Mulher, Família e Direitos Huma      192
# ...

# %%
df.columns
# Out:
# Index(['CÓDIGO ÓRGÃO SUPERIOR', 'NOME ÓRGÃO SUPERIOR', 'CÓDIGO ÓRGÃO',
#        'NOME ÓRGÃO', 'CÓDIGO UNIDADE GESTORA', 'NOME UNIDADE GESTORA',
#        'CATEGORIA ECONÔMICA', 'ORIGEM RECEITA', 'ESPÉCIE RECEITA',
#        'DETALHAMENTO', 'VALOR PREVISTO ATUALIZADO', 'VALOR LANÇADO',
#        'VALOR REALIZADO', 'PERCENTUAL REALIZADO', 'DATA LANÇAMENTO',
#        'ANO EXERCÍCIO'],
#       dtype='object')

# %%
df['VALOR PREVISTO ATUALIZADO'] = df['VALOR PREVISTO ATUALIZADO'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO INICIAL (R$)'] = pd.to_numeric(df2['ORÇAMENTO INICIAL (R$)'], downcast="float")

df['VALOR LANÇADO'] = df['VALOR LANÇADO'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO ATUALIZADO (R$)'] = pd.to_numeric(df2['ORÇAMENTO ATUALIZADO (R$)'], downcast="float")

df['VALOR REALIZADO'] = df['VALOR REALIZADO'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO EMPENHADO (R$)'] = pd.to_numeric(df2['ORÇAMENTO EMPENHADO (R$)'], downcast="float")

df['PERCENTUAL REALIZADO'] = df['PERCENTUAL REALIZADO'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO REALIZADO (R$)'] = pd.to_numeric(df2['ORÇAMENTO REALIZADO (R$)'], downcast="float")

# %%
teste = df.groupby(['NOME ÓRGÃO SUPERIOR']).sum()
#df[df['NOME ÓRGÃO SUPERIOR'] == 'Ministério da Defesa']

# %%
teste.head(5)
# Out:
#                                                CÓDIGO ÓRGÃO SUPERIOR  \
# NOME ÓRGÃO SUPERIOR
# Advocacia-Geral da União                                      126000
# Controladoria-Geral da União                                   37000
# Ministério da Agricultura, Pecuária e Abastec              123420000
# Ministério da Cidadania                                     27610000
# Ministério da Ciência, Tecnologia, Inovações               110520000
#
#                                                CÓDIGO ÓRGÃO  \
# NOME ÓRGÃO SUPERIOR
# Advocacia-Geral da União                             126000
# Controladoria-Geral da União                          37000
# Ministério da Agricultura, Pecuária e Abastec     130241977
# Ministério da Cidadania                            27610223
# Ministério da Ciência, Tecnologia, Inovações      105147108
#
#                                                CÓDIGO UNIDADE GESTORA  \
# NOME ÓRGÃO SUPERIOR
# ...

# %%
df2.head(5)
# Out:
#    EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  \
# 0       2019                  20000  Presidência da República
# 1       2019                  20000  Presidência da República
# 2       2019                  20000  Presidência da República
# 3       2019                  20000  Presidência da República
# 4       2019                  20000  Presidência da República
#
#    CÓDIGO ÓRGÃO SUBORDINADO                          NOME ÓRGÃO SUBORDINADO  \
# 0                     24208  Instituto Nacional de Tecnologia da Informação
# 1                     20101                        Presidência da República
# 2                     20101                        Presidência da República
# 3                     24208  Instituto Nacional de Tecnologia da Informação
# 4                     24208  Instituto Nacional de Tecnologia da Informação
#
#    CÓDIGO UNIDADE ORÇAMENTÁRIA                 NOME UNIDADE ORÇAMENTÁRIA  \
# ...

# %%
df2['ORÇAMENTO INICIAL (R$)'] = df2['ORÇAMENTO INICIAL (R$)'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO INICIAL (R$)'] = pd.to_numeric(df2['ORÇAMENTO INICIAL (R$)'], downcast="float")

df2['ORÇAMENTO ATUALIZADO (R$)'] = df2['ORÇAMENTO ATUALIZADO (R$)'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO ATUALIZADO (R$)'] = pd.to_numeric(df2['ORÇAMENTO ATUALIZADO (R$)'], downcast="float")

df2['ORÇAMENTO EMPENHADO (R$)'] = df2['ORÇAMENTO EMPENHADO (R$)'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO EMPENHADO (R$)'] = pd.to_numeric(df2['ORÇAMENTO EMPENHADO (R$)'], downcast="float")

df2['ORÇAMENTO REALIZADO (R$)'] = df2['ORÇAMENTO REALIZADO (R$)'].str.replace(",",".",regex=True).astype(float)
#df2['ORÇAMENTO REALIZADO (R$)'] = pd.to_numeric(df2['ORÇAMENTO REALIZADO (R$)'], downcast="float")

# %%
teste = df2.groupby(['NOME ÓRGÃO SUPERIOR']).sum()

# %%
teste
# Out:
#                                                     EXERCÍCIO  \
# NOME ÓRGÃO SUPERIOR
# Advocacia-Geral da União                               109026
# Controladoria-Geral da União                           121140
# Ministério da Agricultura, Pecuária e Abastecim...    2117931
# Ministério da Cidadania                               1558668
# Ministério da Ciência, Tecnologia, Inovações e ...    1940259
# Ministério da Defesa                                  3858309
# Ministério da Economia                                5307951
# Ministério da Educação                               21199500
# Ministério da Infraestrutura                          2333964
# Ministério da Justiça e Segurança Pública             2039190
# Ministério da Mulher, Família e Direitos Humanos       575415
# Ministério da Saúde                                   2881113
# Ministério das Comunicações                            337173
# Ministério das Relações Exteriores                     468408
# ...
